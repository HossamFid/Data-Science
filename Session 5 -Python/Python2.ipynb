# %%
x = 5
print(type(x))
# Out:
# <class 'int'>

# %%
a = 1+2j
print(type(a))
# Out:
# <class 'complex'>

# %%
float(5)

# %%
x=25
y=float(x)
print(y)
# Out:
# 25.0

# %%
s = '''A mu
print(s)
# Out:
# A multiline
# string

# %%
name = "doaa" 
print(name.lower())
# Out:
# doaa

# %%
first_name = "doaa"
last_name = "mostafa"
print(first_name, last_name )

# %%
print('doaa'+ 'mostafa')
# Out:
# doaamostafa

# %%
s ="Hello world"

print(s[])
# Out:
# d

# %%
a = [2, 12, 77, 6 ,4 ,7 ]

print(sorted(a))
# Out:
# [2, 4, 6, 7, 12, 77]

# %%
a = [5,10,15,20,25,30,35,40]

# a[2] = 15
print("a[2] = ", a[2])

# a[0:3] = [5, 10, 15]
print("a[0:3] = ", a[0:3])

# a[5:] = [30, 35, 40]
print("a[5:] = ", a[5:])

# %%
a = [1, 2, 3]
a[2] = 4
print(a)

# %%
x = [0] * 1000

# %%
sum(x)

# %%
a[]  # list
t() # tuple
s{} # set

# %%
t = (5,'program', 1+3j)

print(t[1:2])
# Out:
# ('program',)

# %%
t = (5,'program', 1+3j)

# t[1] = 'program'
print("t[1] = ", t[1])

# t[0:3] = (5, 'program', (1+3j))
print("t[0:3] = ", t[0:3])

# Generates error
# Tuples are immutable
t[0] = 10

# %%
x=False
print(x)
# Out:
# <class 'bool'>

# %%
a = {5,2,3,1,4}

print(type(a))
# Out:
# <class 'set'>

# %%
x=[1,2,2,3,3,3]
y=(1,2,2,3,3,3)
a = {7,1,"doaa",2,.6,3,3 ,-1}
print(x)
print(y)
print(a)
# Out:
# [1, 2, 2, 3, 3, 3]
# <built-in method sort of list object at 0x7f2a158320c8>

# %%
a = {1,2,3}
x[1]
# Out:
# 2

# %%
d = {1:'value','key':2}
type(d)
# Out:
# value

# %%
d = {1:'value','key':2}
print(type(d))

print("d[1] = ", d[1]);

print("d['key'] = ", d['key']);

# Generates error
print("d[2] = ", d[2]);

# %%
x=3
if x>10:
    print("x is big.")
if x<= 10:
    print("x is small.")

# %%
x=3
if x>10:
    print("x is big.")
elif x>0:
    print("x is small.")
else:
    print("x is not positive.")

# %%
for i in range(5):
      print(i)

# %%
for i in range(1,10,2):
  print(i)

# %%
for i in range(10):
  if i%3 != i%2:
    continue
  print(i)
